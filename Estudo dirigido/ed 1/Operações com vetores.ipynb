# %%
from operator import add, mul
import math

def SomaVet():
    G = []
    a = 0
    e = 0
    V = int(input("Número de vetores que você quer: "))
    E = input("Usar vetor salvo para o procedimento? (sim ou nao) ")
    if E == 'nao':
        for i in range(V):
            x = [int(i) for i in input("Escreva seu vetor separando-o por espaço: ").split()]
            if len(x) == S:
                G.append(x)
            if len(x) != S:
                print("Dimensão dos vetores diferente da dimensão definida! ")
                e = 1
                break
            print("")
        for i in range(V-1):
            if e == 1:
                break
            else:
                G[a+1] = list(map(add,G[a],G[a+1]))
                a = a + 1
                D = G[a]
                return(D)
    if E == 'sim':
        if F == []:
            print("\nVocê ainda não salvou nenhum vetor! ")
        else:
            print("Você salvou o vetor:",F[-1])
            G.append(F[-1])
            for i in range(V-1):
                x = [int(i) for i in input("Escreva seu vetor separando-o por espaço: ").split()]
                if len(x) == S:
                    G.append(x)
                if len(x) != S:
                    print("Dimensão dos vetores diferente da dimensão definida! ")
                    e = 1
                    break
                print("")
            for i in range(V-1):
                if e == 1:
                    break
                else:
                    G[a+1] = list(map(add,G[a],G[a+1]))
                    a = a + 1
                    D = G[a]
                    return(D)

def MulEsc():
    E = input("Usar vetor salvo para o procedimento? (S para sim,N para não) ")
    b = 0
    if E == 'nao':
        x = [int(i) for i in input("Escreva seu vetor separando-o por espaço: ").split()]
        if len(x) != S:
            print("Dimensão dos vetores diferente da dimensão definida! ")
        if len(x) == S:
            M = int(input("Digite a escalar: "))
            for i in range(len(x)):
                x[b]*=M
                b += 1
            D = x
            return (D)
    if E == 'sim':
        if len(F) == 0:
            print("\nVocê ainda não salvou nenhum vetor! ")
        else:
            print("Utilizaremos o vetor:",F[-1])
            R = F[-1]
            if len(R) != S:
                print("Dimensão dos vetores diferente da dimensão definida! ")
            if len(R) == S:
                M = int(input("Digite a escalar: "))
                for i in range(len(R)):
                    R[b]*=M
                    b += 1
                D = R
                return (D)
    

def CombLin():
    E = input("Usar vetor salvo para o procedimento? (S para sim,N para não) ")
    G = []
    c = 0
    if E == 'sim':
        if len(F) == 0:
            print("\nVocê ainda não salvou nenhum vetor! ")
        else:
            print("Utilizaremos o vetor:",F[-1])
            R = F[-1]
            q = [int(i) for i in input("Vetor 2: ").split()]
            if len(q) != S:
                print("Dimensão dos vetores diferente da dimensão definida! ")
            if len(R) and len(q) == S:
                M = int(input("Escalar 1: "))
                N = int(input("Escalar 2: "))
                for i in range(len(q)):
                    R[c]*=M
                    q[c]*=N
                    c += 1
                    G.append(R)
                    G.append(q)
                c = 0
                D = list(map(add,G[c],G[c+1]))
                return(D)
    if E == 'nao':
        Q = [int(i) for i in input("Vetor 1: ").split()]
        q = [int(i) for i in input("Vetor 2: ").split()]
        if len(Q) or len(q) != S:
            print("Dimensão dos vetores diferente da dimensão definida! ")
        if len(Q) and len(q) == S:
            M = int(input("Escalar 1: "))
            N = int(input("Escalar 2: "))
            for i in range(len(q)):
                Q[c]*=M
                q[c]*=N
                c += 1
                G.append(Q)
                G.append(q)
            c = 0
            D = list(map(add,G[c],G[c+1]))
            return(D)

def NormaVet():
    s = 0
    d = 0
    E = input("Usar vetor salvo para o procedimento? (S para sim,N para não) ")
    if E == 'nao':
        x = [int(i) for i in input("Escreva seu vetor separando-o por espaço: ").split()]
        if len(x) == S:
            for i in range(len(x)):
                s += (x[d])**2
                d +=1
            D = s**(1/2)
            return (D)
        else:
            print("Dimensão dos vetores diferente da dimensão definida! ")
    if E == 'sim':
        if len(F) != 0:
            print("Esse é o vetor salvo que será utilizado: ",F[-1])
            R = F[-1]
            if len(R) == S:
                for i in range(len(R)):
                    s += (R[d])**2
                    d +=1
                D = s**(1/2)
                return (D)
            else:
                print("Dimensão dos vetores diferente da dimensão definida! ")
        else:
            print("Você está tentando acessar uma posição salva mas nenhuma foi criada")
                    
def ProdInt():
    G = []
    E = input("Usar vetor salvo para o procedimento? (S para sim,N para não) ")
    f = 0
    V = int(input("Número de vetores a serem multiplicados: "))
    if E == 'nao':
        for i in range(V):
            x = [int(i) for i in input("Escreva seu vetor separando-o por espaço: ").split()]
            G.append(x)
            print("")
            if len(x) != S:
                print("Você usou um vetor de tamanho diferente da dimensão que você definiu no início")
                break
        if len(x) == S:
            for i in range(V-1):
                G[f+1] = list(map(mul,G[f],G[f+1]))
                f = f + 1
                D = G[f]
            return (D)
        if len(x) != S:
            return(print(""))
    if E == 'sim':
        if len(F) == 0:
            print("Você está tentando acessar uma posição salva mas nenhuma foi criada")
        else:
            R = F[-1]
            G.append(R)
            print("Esse é o vetor que será utilizado pois estava salvo: ",R)
            for i in range(V-1):
                x = [int(i) for i in input("Escreva seu vetor separando-o por espaço: ").split()]
                G.append(x)
                print("")
                if len(x) != S:
                    print("Você usou um vetor de tamanho diferente da dimensão que você definiu no início")
                    break
            if len(x) == S:
                for i in range(V-1):
                    G[f+1] = list(map(mul,G[f],G[f+1]))
                    f = f + 1
                    D = G[f]
                return (D)
            if len(x) != S:
                return(print(""))


def DistVet():
    w = 0
    y = 0
    E = input("Usar vetor salvo para o procedimento? (S para sim,N para não) ")
    if E == 'sim':
        if len(F) != 0:
            R = F[-1]
            print("Esse é o vetor que será utilizado pois estava salvo: ",R)
            q = [int(i) for i in input("Vetor 2: ").split()]
            if len(R) and len(q) == S:
                for i in range(len(R)):
                    w += (R[y]-q[y])**2
                    y += 1
                D = w**(1/2)
                return(D)
            if len(R) or len(q) != S:
                print("Você usou um vetor de tamanho diferente da dimensão que você definiu no início")
        else:
            print("Você está tentando acessar uma posição salva mas nenhuma foi criada")
    if E == 'nao':
        Q = [int(i) for i in input("Vetor 1: ").split()]
        q = [int(i) for i in input("Vetor 2: ").split()]
        if len(Q) and len(q) == S:
            for i in range(len(Q)):
                w += (Q[y]-q[y])**2
                y += 1
            D = w**(1/2)
            return(D)
        if len(Q) or len(q) != S:
            print("Você usou um vetor de tamanho diferente da dimensão que você definiu no início")


def AnguloVet():
    E = input("Usar vetor salvo para o procedimento? (S para sim,N para não) ")
    if E == 'sim':
        if len(F) == 0:
            print("Você quer utilizar um vetor salvo, mas não existem vetores salvos")
        else:
            R = F[-1]
            print("Esse é o vetor que será utilizado pois estava salvo: ",R)
            v2= [int(i) for i in input("Vetor 2: ").split()]
            if len(R) and len(v2) == S:
                def multiplicaçâoP(R, v2):
                    return sum((a*b) for a, b in zip(R, v2))
                def comprimento(v):
                    return math.sqrt(multiplicaçâoP(v, v))
                def angulo(R, v2):
                    return math.acos(multiplicaçâoP(R, v2) / (comprimento(R) * comprimento(v2)))
                D = angulo(R,v2)
                return(angulo(R,v2))
            else:
                print("Um dos seus vetores é de uma dimensão diferente")
    if E == 'nao':
        v1= [int(i) for i in input("Vetor 1: ").split()]
        v2= [int(i) for i in input("Vetor 2: ").split()]
        if len(v1) and len(v2) == S:
            def multiplicaçâoP(v1, v2):
                return sum((a*b) for a, b in zip(v1, v2))
            def comprimento(v):
                return math.sqrt(multiplicaçâoP(v, v))
            def angulo(v1, v2):
                return math.acos(multiplicaçâoP(v1, v2) / (comprimento(v1) * comprimento(v2)))
            D = angulo(v1,v2)
            return(angulo(v1,v2))
        if len(v1) or len(v2) != S:
            print("Você usou um vetor de tamanho diferente da dimensão que você definiu no início")

# %%
print("Calculadora Vetorial!\nIntegrantes: Luis Carmona, Lucas Galdino e Vinicius Rabello\nMatemática Aplicada\n")
S = int(input("Número de dimensões do seu vetor: "))
Ç = 0
F = []
D = 0
E = 0
while True:
    print("\nEscolha uma das opções abaixo:\n1-Soma Vetorial\n2-Multiplicação por escalar\n3-Combinação linear de 2 vetores")
    print("4-Norma vetorial\n5-Produto Interno\n6-Distância entre dois vetores\n7-Ângulo entre dois vetores")
    print("8-Alterar Dimensão\n9-Sair")
    X = int(input("\nEscolha a opção desejada: "))
    if X == 1:
        D = SomaVet()
    if X == 2:
        D = MulEsc()
    if X == 3:
        D = CombLin()
    if X == 4:
        D = NormaVet()
    if X == 5:
        D = ProdInt()
    if X == 6:
        D = DistVet()
    if X == 7:
        D = AnguloVet()
    if X == 8:
        print("Você escolheu alterar a dimensâo do seu vetor!")
        S = int(input("Qual a nova dimensão da sua calculadora? "))
    if X == 9:
        print("Você escolheu sair do programa!")
        break
    if D != 0:
        print("\nDiga o próximo procedimento?\n1-Salvar resultado\n2-Imprimir resultado\n3-Salvar resultado e imprimi-lo")
        print("Caso seu programa não tenha gerado resultados por erro, aperte imprimir e tente novamente")
        U = int(input("Próximo procedimento: "))
        if U == 1:
            F.append(D)
        if U == 2:
            print("\n",D)
        if U == 3:
            F.append(D)
            print("\n",D)
        D = 0
    Ç += 1
if Ç == 0:
    print("\nVocê não fez nenhuma operação")
if Ç == 1:
    print("\nVocê fez ",Ç," operação!")
if Ç >= 2:
    print("\nVocê fez ",Ç," operações!")
# Out:
# Calculadora Vetorial!
# Integrantes: Luis Carmona, Lucas Galdino e Vinicius Rabello
# Matemática Aplicada
#
# Número de dimensões do seu vetor: 2
#
# Escolha uma das opções abaixo:
# 1-Soma Vetorial
# 2-Multiplicação por escalar
# 3-Combinação linear de 2 vetores
# 4-Norma vetorial
# 5-Produto Interno
# 6-Distância entre dois vetores
# 7-Ângulo entre dois vetores
# 8-Alterar Dimensão
# 9-Sair
#
# Escolha a opção desejada: 1
# Número de vetores que você quer: 2
# Usar vetor salvo para o procedimento? (sim ou nao) s
#
# Diga o próximo procedimento?
# 1-Salvar resultado
# 2-Imprimir resultado
# 3-Salvar resultado e imprimi-lo
# Caso seu programa não tenha gerado resultados por erro, aperte imprimir e tente novamente
# Próximo procedimento: 4
#
# Escolha uma das opções abaixo:
# 1-Soma Vetorial
# 2-Multiplicação por escalar
# 3-Combinação linear de 2 vetores
# 4-Norma vetorial
# 5-Produto Interno
# 6-Distância entre dois vetores
# 7-Ângulo entre dois vetores
# 8-Alterar Dimensão
# ...
