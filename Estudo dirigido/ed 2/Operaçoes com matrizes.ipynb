# %%
memoria = []
backup = []

def abrir():
    l = []
    with open('matrizes.txt', 'r') as f:
        for line in f:
            line = line.strip()
            if len(line) > 0:
                l.append(list(map(int, line.split(','))))
    memoria.append(l)
    return l

def identidade(n):
    m=[[0 for x in range(n)] for y in range(n)]
    for i in range(0,n):
        m[i][i] = 1
    memoria.append(m)
    return m

def VerMatriz(ind):
    print()
    for s in memoria[ind]:
        print(s)
    print()

def CriarM(a,b):
    matriz = []
    print("")
    c = 0
    for i in range (a):
        linha = [int(i) for i in input("Escreva sua linha separando-a por espaço: ").split()]
        matriz.append(linha)
        while len(linha) < b:
            linha.append(1)
        while len(linha) > b:
            del linha[-1] 
    memoria.append(matriz)
    VerMatriz(len(memoria) - 1)
    return matriz

def VerMemoria(ini, fim):
    i = 0
    if ini < 0: 
        ini = 0
    if fim >= len(memoria): 
        fim = len(memoria) - 1
    while i <= fim and ini <= i:
        VerMatriz(i)
        i += 1

def VerMemoriaToda():
    if len(memoria) != 0:
        for i in range(len(memoria)):
            VerMatriz(i)
            i += 1
    else:
        print("Sua memória está vazia")

def ApagarMatriz(ind,fin):
    print("Essas serão as matrizes que você vai apagar, tem certeza disso?(S para sim e N para não) ")
    VerMemoria(ind,fin)
    confirma = (input("----> ")).lower()
    print("")
    if confirma == 's':
        del memoria[ind:fin+1]
    elif confirma == 'n':
        pass
    else:
        ApagarMatriz(ind,fin)

def ApagarMemoria():
    try:
        print("Você selecionou apagar a memoria toda")
        K = input("Tem certeza disso? (s para sim e n para nao)")
        if K == 's':
            memoria.clear()
            print("Sua memoria está zerada")
        if K == 'n':
            pass
    except:
        print("Você digitou algo errado ou não digitou nada, para apagar tente novamente")

def SomarMatrizes(a,b):
    try:
        if len(a[0]) == len(b[0]) and len(a) == len(b):
            Mat = []    
            for i in range(len(a)):
                linha = []
                for j in range(int(len(a[i]))):
                    linha.append(int(a[i][j]) + int(b[i][j]))
                Mat.append(linha)
            memoria.append(Mat)
            return Mat
        else:
            print("Suas matrizes possuem tamanho diferente, impossivel somar")
    except:
        print("Ops... Algo deu errado, tente novamente")

def SubtrairMatrizes(a,b):
    try:
        if len(a[0]) == len(b[0]) and len(a) == len(b):
            Mat = []    
            for i in range(len(a)):
                linha = []
                for j in range(int(len(a[i]))):
                    linha.append(int(a[i][j]) - int(b[i][j]))
                Mat.append(linha)
            memoria.append(Mat)
            return Mat
        else:
            print("Suas matrizes possuem tamanho diferente, impossivel subtrair")
    except:
        print("Matrizes possuem tamanho diferente, não é possivel subtrair")

def Escalar(a,b):
    Mat = []    
    for i in range(len(a)):
        linha = []
        for j in range(int(len(a[i]))):
            linha.append(int(a[i][j]) * b)
        Mat.append(linha)
    memoria.append(Mat)
    return Mat

def SomaLC(a,b):
    memoria.append(K)
    LC = input("Você quer somar uma linha ou uma coluna? ")
    if LC == 'linha':
        Lin = int(input("Qual linha você quer somar? (contagem começa no 1) ")) -1
        for j in range(int(len(a[Lin]))):
            a[Lin][j] = (int(a[Lin][j])+b[j])
        memoria.append(a)
        return a
    if LC == 'coluna':
        Col = int(input("Qual é a coluna que você quer somar? (contagem começa no 1) ")) -1
        for i in range(len(a)):
            a[i][Col] = (int(a[i][Col])+b[i])
        memoria.append(a)
        return a

def EscalarLC(a,b):
    LC = input("Você quer multiplicar uma linha ou uma coluna? ")
    if LC == 'linha':
        Lin = int(input("Qual linha você quer multiplicar por escalar? (contagem começa no 1)")) -1
        for j in range(int(len(a[Lin]))):
            a[Lin][j] = (int(a[Lin][j])*b)
        return a
    if LC == 'coluna':
        Col = int(input("Qual é a coluna que você quer multiplicar por escalar? (contagem começa no 1)")) - 1
        for i in range(len(a)):
            a[i][Col] = (int(a[i][Col])*b)
    memoria.append(a)
    return a

def MultMat(A, B):
    LinhasA = len(A)
    ColunasA = len(A[0])
    LinhasB = len(B)
    ColunasB = len(B[0])
    if ColunasA != LinhasB:
        print("Você nao pode multiplicar essas matrizes")
        return
    C = [[0 for lin in range(ColunasB)] for col in range(LinhasA)]
    for i in range(LinhasA):
        for j in range(ColunasB):
            for k in range(ColunasA):
                C[i][j] += A[i][k] * B[k][j]
    memoria.append(C)
    return C

def Tranposicao(a):
    Mat = []
    linhas = len(a)
    colunas = len(a[0])
    for i in range(colunas):
        linha = []
        for j in range(linhas):
            linha.append(a[j][i])
        Mat.append(linha)
    memoria.append(Mat)
    return Mat
    
def Permutadora2x2(a):
    Mat = []
    PLC = input("Permutar linhas ou colunas? ")
    if PLC == 'linhas':
        A =[[0,1],[1,0]]
        Mat = MultMat(A,a)
    if PLC == 'colunas':
        A =[[0,1],[1,0]]
        Mat = MultMat(a,A)
    memoria.append(Mat)
    return Mat

def Inversora2x2(a):
    A =[[0,1],[1,0]]
    Mat = MultMat(a,A)
    Mat = MultMat(A,Mat)
    memoria.append(Mat)
    return Mat

def Backup():
    for i in range(len(memoria)):
        backup.append(memoria[i])
    print("O seu Backup foi criado/atualizado ")
    return backup

def LerBackup():
    if len(backup) != 0:
        for i in range(len(backup)):
            print(backup[i])
    else:
        print("Seu Backup está vazio")

def AttMemoria():
    print("Você selecionou atualizar sua memoria com o Backup, isso vai destruir sua memoria atual.")
    dec = (input("Você tem certeza disso? (s para sim e n para não) ")).lower()
    if dec == 's':
        memoria.clear()
        for s in backup:
            memoria.append(s)
        VerMemoriaToda()
    elif dec == 'n':
        pass
    else:
        print("Você digitou algo diferente de n ou s, tente novamente")
        AttMemoria()
    return memoria

# %%
print("Bem vindo a calculadora matricial\nAlunos:\nLuis Miguel Carmona\nVinicius Rabello\nLucas Galdino\nPedro Gueventer\n")
T = input("Você quer utilizar a matriz do seu arquivo .txt? (s para sim e n para não)")
if T == 's':
    abrir()
else:
    pass
while True:
    print('\n+==================== Calculadora Matricial ====================+')
    print('|                                                               |')
    print('|0.Criar Matriz                                                 |')
    print('|1.Soma ou Subtração Matricial (C = A + B ou C = A - B)         |')
    print('|2.Multiplicação por Escalar (C = aA onde a é um número inteiro)|')
    print('|3.Multiplicação Matricial (C = A x B)                          |')
    print('|4.Transposição                                                 |')
    print('|5.Permutar Duas Linhas ou Duas Colunas de posição (matriz 2x2) |')
    print('|6.Somar à uma Linha outra Linha ou à uma Coluna outra Coluna   |')
    print('|7.Multiplicar uma única Linha ou Coluna, por uma Escalar       |')
    print('|8.Inversão de Matrizes Quadradas 2x2                           |')
    print('|9.Backup                                                       |')
    print('|10.Operações com a memória                                     |')
    print('|11.Criador de Matriz Identidade                                |')
    print('|12.Sair do programa                                            |')
    print('|                                                               |')
    print('+===============================================================+\n')
    try:
        X = int(input('Escolha a opção desejada: '))
    except:
        print("Você não digitou nada ou algo que não é um número, portanto o programa irá se fechar")
        X = 12
    if X == 0:
        try:
            a = int(input('\nEscolha o Número de Linhas: '))
            b = int(input('\nEscolha o Número de Colunas: '))
            CriarM(a,b)
        except:
            print("Você deixou algo em branco ou digitou algo errado!")
    if X == 1:
        print('\n+===============================================================+')
        print('|                                                               |')
        print('|1.Soma Matricial (C = A + B)                                   |')
        print('|2.Subtração Matricial (C = A - B)                              |')
        print('|                                                               |')
        print('+===============================================================+\n')
        try:
            S = int(input('Escolha a opção desejada: '))
            Us = input("Você quer usar matrizes salvas? (s para sim e n para nao) ")
            if S == 1:
                if Us == 's':
                    if len(memoria) == 0:
                        print("Sua memória está vazia")
                        pass
                    else:
                        try:
                            print("")
                            VerMemoriaToda()
                            print()
                            a = int(input('Escolha A (listagem começa no 0): '))
                            b = int(input('Escolha B (listagem começa no 0): '))
                            print()
                            SomarMatrizes(memoria[a],memoria[b])
                            VerMatriz(len(memoria) - 1)
                        except:
                            print("Você não digitou um número ou sua lista está fora de alcance")
                if Us == 'n':
                    try:
                        a = int(input('\nEscolha o Número de Linhas: '))
                        b = int(input('\nEscolha o Número de Colunas: '))
                        CriarM(a,b)
                        c = int(input('\nEscolha o Número de Linhas: '))
                        d = int(input('\nEscolha o Número de Colunas: '))
                        CriarM(c,d)
                        SomarMatrizes(memoria[-1],memoria[-2])
                        VerMatriz(len(memoria)-1)
                    except:
                        print("Você não digitou um número ou sua lista está fora de alcance")
            if S == 2:
                if Us == 's':
                    if len(memoria) == 0:
                        print("Sua memória está vazia")
                        pass
                    else:
                        try:
                            print("")
                            VerMemoriaToda()
                            print()
                            a = int(input('Escolha A (listagem começa no 0): '))
                            b = int(input('Escolha B (listagem começa no 0): '))
                            print()
                            SubtrairMatrizes(memoria[a],memoria[b])
                            VerMatriz(len(memoria) - 1)
                        except:
                            print("Você não digitou um número")
                if Us == 'n':
                    try:
                        a = int(input('\nEscolha o Número de Linhas: '))
                        b = int(input('\nEscolha o Número de Colunas: '))
                        CriarM(a,b)
                        c = int(input('\nEscolha o Número de Linhas: '))
                        d = int(input('\nEscolha o Número de Colunas: '))
                        CriarM(c,d)
                        SubtrairMatrizes(memoria[-1],memoria[-2])
                        VerMatriz(len(memoria)-1)
                    except:
                        print("Você não digitou um número")
        except:
            print("Você deixou algo em branco...")
    if X == 2:
        try:
            Us = input("Você quer usar uma matriz salva? (s para sim e n para não)")
            if Us == 's':
                if len(memoria) == 0:
                    print("Sua memória está vazia")
                    pass
                else:
                    print("")
                    VerMemoriaToda()
                    print()
                    A = int(input('Escolha a matriz que você quer multiplicar(ordem começa no 0): '))
                    print()
                    a = int(input('Escolha o escalar: '))
                    print()
                    Escalar(memoria[A],a)
                    print("")
                    VerMatriz(len(memoria) - 1)
            if Us == 'n':
                print("\nAgora você vai criar a matriz que você vai utilizar")
                a = int(input('\nEscolha o Número de Linhas: '))
                b = int(input('\nEscolha o Número de Colunas: '))
                CriarM(a,b)
                Esc = int(input("escalar: "))
                Escalar(memoria[-1],Esc)
                VerMatriz(len(memoria)-1)
        except:
            print("Algo deu errado...\nTente novamente")
    if X == 3:
        try:
            Us = input("Você quer utilizar uma matriz da memória? (s para sim e n para não)")
            if Us == 's':
                if len(memoria) == 0:
                    print("Sua memória está vazia")
                    pass
                else:
                    print("")
                    VerMemoriaToda()
                    print()
                    a = int(input('Escolha A: (contagem começa no 0)'))
                    print()
                    b = int(input('Escolha B: (contagem começa no 0)'))
                    print()
                    MultMat(memoria[a],memoria[b])
                    VerMatriz(len(memoria) - 1)
            if Us == 'n':
                print("\nAgora você vai criar a primeira matriz que você vai utilizar")
                a = int(input('\nEscolha o Número de Linhas: '))
                b = int(input('\nEscolha o Número de Colunas: '))
                CriarM(a,b)
                print("\nAgora você vai criar a segunda matriz que você vai utilizar")
                c = int(input('\nEscolha o Número de Linhas: '))
                d = int(input('\nEscolha o Número de Colunas: '))
                CriarM(c,d)
                MultMat(memoria[-2],memoria[-1])
                VerMatriz(len(memoria)-1)
        except:
            print("Ops...Algo deu errado")
    if X == 4:
        try:
            Ue = input("Você quer utilizar uma matriz salva para a operação? (s para sim e n para não)")
            if Ue == 's':
                if len(memoria) == 0:
                    print("Sua memória está vazia")
                    pass
                else:
                    print("")
                    VerMemoriaToda()
                    print()
                    a = int(input('Escolha sua Matriz: (Numeracao comeca no 0)'))
                    print()
                    Tranposicao(memoria[a])
                    VerMatriz(len(memoria) - 1)
            if Ue == 'n':
                print("\nAgora você vai criar a matriz que você vai utilizar")
                a = int(input('\nEscolha o Número de Linhas: '))
                b = int(input('\nEscolha o Número de Colunas: '))
                print("")
                CriarM(a,b)
                Tranposicao(memoria[-1])
                VerMatriz(len(memoria)-1)
        except:
            print("Ops...Algo deu errado")
    if X == 5:
        try:
            Ue = input("Você quer utilizar uma matriz salva para a operação? (s para sim e n para não)")
            if Ue == 's':
                if len(memoria) == 0:
                    print("Sua memória está vazia")
                    pass
                else:
                    print("A permutadora só está funcionando para matrizes 2x2")
                    VerMemoriaToda()
                    print()
                    a = int(input('Escolha sua Matriz: '))
                    if len(memoria[a][0]) == 2 and len(memoria[a]) == 2:
                        Permutadora2x2(memoria[a])
                        VerMatriz(len(memoria) - 1)
                    else:
                        print("Sua Matriz tem um tamanho diferente de 2x2")
            if Ue == 'n':
                print("\nAgora você vai criar a matriz que você vai utilizar")
                CriarM(2,2)
                Permutadora2x2(memoria[-1])
                VerMatriz(len(memoria)-1)
        except:
            print("Ops...Algo deu errado :(")
    if X == 6:
        try:
            Ut = input("Você quer utilizar uma matriz salva? (digite s para sim e n para não)")
            if Ut == 's':
                if len(memoria) == 0:
                    print("Sua memória está vazia")
                    pass
                else:
                    VerMemoriaToda()
                    a = int(input("Escolha sua Matriz: (listagem começa no 0)"))
                    b = [int(i) for i in input("Escreva sua linha/coluna separando-a por espaço: ").split()]
                    print(b)
                    SomaLC(memoria[a],b)
                    VerMatriz(len(memoria)-1)
            if Ut == 'n':
                print("\nAgora você vai criar a matriz que você vai utilizar")
                a = int(input('\nEscolha o Número de Linhas: '))
                b = int(input('\nEscolha o Número de Colunas: '))
                CriarM(a,b)
                c = [int(i) for i in input("Escreva sua linha/coluna separando-a por espaço: ").split()]
                SomaLC(memoria[-1],c)
                VerMatriz(len(memoria)-1)
        except:
            print("Ops... Algo deu errado")
    if X == 7:
        try:
            Ut = input("Você quer utilizar uma matriz da memoria (s para sim e n para não)? ")
            if Ut == 's':
                if len(memoria) == 0:
                    pass
                else:
                    print("")
                    VerMemoriaToda()
                    print()
                    a = int(input('Escolha sua Matriz: (contagem começa no 0) '))
                    b = int(input('\nEscolha a Escalar: '))
                    EscalarLC(memoria[a],b)
                    VerMatriz(len(memoria) - 1)
            if Ut == 'n':
                print("\nAgora você vai criar a matriz que você vai utilizar")
                a = int(input('\nEscolha o Número de Linhas: '))
                b = int(input('\nEscolha o Número de Colunas: '))
                CriarM(a,b)
                c = int(input('\nEscolha a Escalar: '))
                EscalarLC(memoria[-1],c)
                VerMatriz(len(memoria)-1)
        except:
            print("Algo deu errado...\nTente novamente")

    if X == 8:
        try:
            Ut = (input("Você quer utilizar uma matriz da memoria (s para sim e n para não) ")).lower()
            if Ut == 's':
                if len(memoria) == 0:
                    print("Sua memória esta vazia...\nTente novamente")
                    pass
                else:
                    print("")
                    VerMemoriaToda()
                    print()
                    a = int(input('Escolha sua Matriz: '))
                    Inversora2x2(memoria[a])
                    VerMatriz(-1)
            if Ut == 'n':
                print("Você vai criar uma matriz 2x2")
                CriarM(2,2)
                Inversora2x2(memoria[-1])
                VerMatriz(-1)
        except:
            print("Algo deu errado...\nTente novamente")
    
    if X == 9:
        try:
            print("Agora você tem que escolher o que quer fazer: \n")
            print('\n+===============================================================+')
            print('|1.Atualizar memória com o Backup                               |')
            print('|2.Fazer Backup da memória                                      |')
            print('|3.Ver Backup                                                   |')
            print('+===============================================================+\n')
            esc = int(input("escolha: "))
            if esc == 1:
                AttMemoria()
            if esc == 2:
                Backup()
            if esc == 3:
                LerBackup()
        except:
            print("Ops... algo deu errado")
    if X == 10:
        try:
            print("Você selecionou o menu referente a memoria, essas são as suas opções")
            print('\n+===============================================================+')
            print('|1.Ver memoria completa                                         |')
            print('|2.Ver parte da memoria                                         |')
            print('|3.Zerar a memoria                                              |')
            print('|4.Apagar parte da memoria                                      |')
            print('+===============================================================+\n')
            esc = int(input("escolha: "))
            if esc == 1:
                try:
                    VerMemoriaToda()
                except:
                    print("Ops... Algo deu errado")
            if esc == 2:
                try:
                    A1 = int(input("Você quer ver a memoria começando em qual número? (listagem começa no 0) "))
                    A2 = int(input("Você quer ver a memoria terminando em qual número? (listagem começa no 0, se quiser ir até o ultimo digite -1) "))
                    VerMemoria(A1,A2)
                except:
                    print("Ops... Algo deu errado")
            if esc == 3:
                try:
                    ApagarMemoria()
                except:
                    print("Ops... Algo deu errado")
            if esc == 4:
                try:
                    A1 = int(input("Você quer apagar a memoria começando em qual número? (listagem começa no 0) "))
                    A2 = int(input("Você quer apagar a memoria terminando em qual número? (listagem começa no 0, se quiser ir até o ultimo digite -1) "))
                    ApagarMatriz(A1,A2)
                except:
                    print("Ops... Algo deu errado")
        except:
            print("Ops...Algo deu errado")
    if X == 11:
        try:
            N = int(input("Tamnho da sua matriz identidade"))
            identidade(N)
        except:
            print("Ops...Algo deu errado")
    if X == 12:
        print("Você saiu do programa")
        break

print("Sua memoria fechou assim:")
VerMemoriaToda()
# Out:
# Bem vindo a calculadora matricial
# Alunos:
# Luis Miguel Carmona
# Vinicius Rabello
# Lucas Galdino
# Pedro Gueventer
#
# Você quer utilizar a matriz do seu arquivo .txt? (s para sim e n para não)
#
# +==================== Calculadora Matricial ====================+
# |                                                               |
# |0.Criar Matriz                                                 |
# |1.Soma ou Subtração Matricial (C = A + B ou C = A - B)         |
# |2.Multiplicação por Escalar (C = aA onde a é um número inteiro)|
# |3.Multiplicação Matricial (C = A x B)                          |
# |4.Transposição                                                 |
# |5.Permutar Duas Linhas ou Duas Colunas de posição (matriz 2x2) |
# |6.Somar à uma Linha outra Linha ou à uma Coluna outra Coluna   |
# |7.Multiplicar uma única Linha ou Coluna, por uma Escalar       |
# |8.Inversão de Matrizes Quadradas 2x2                           |
# ...
