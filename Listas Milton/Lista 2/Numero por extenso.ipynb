# %%
num = {0: 'Zero',1: 'Um', 2: 'Dois', 3: 'Tres', 4: 'Quatro', 5: 'Cinco', \
      6: 'Seis', 7: 'Sete', 8: 'Oito', 9: 'Nove', 10: 'Dez', \
      11: 'Onze', 12: 'Doze', 13: 'Treze', 14: 'Quatorze',1000: 'Mil', \
      15: 'Quinze', 16: 'Dezesseis', 17: 'Dezessete', 18: 'Dezoito', \
      19: 'Dezenove', 20: 'Vinte', 30: 'Trinta', 40: 'Quarenta', \
      50: 'Cinquenta', 60: 'Sessenta', 70: 'Setenta', 80: 'Oitenta', \
      90: 'Noventa',100: 'Cento',200: 'Duzentos',300: 'Trezentos', \
      400: 'Quatrocentos',500: 'Quinhentos',600: 'Seiscentos', \
      700: 'Setecentos',800: 'Oitocentos',900: 'Novecentos',1234567: ''}
print("Luis Miguel Carmona\nMatemática Aplicada\nDRE-119066153\n")
print("Programa que escreve por extenso um número de até 5 casas solicitado ao usuário\n")
Ç = 1
s = 1
ç = 1
z = int(input("Quantas vezes você quer repetir? "))
for i in range(z):
    N = 0
    M = [str(M) for M in input("Seu número: ")]
    if len(M) == 1:
        N = int(M[0])
        print(num[N])
    elif len(M) == 2:
        N = int(M[0])
        B = int(M[1])
        if N =='2':
            print(num[N*10]+" e "+num[B].lower)
        elif N < 2:
            print(num[(N*10)+B])
        elif N == 2:
            if B == 0:
                print(num[N*10+B])
            else:
                print(num[N*10]+" e "+num[B].lower())
        if N > 2:
            print(num[N*10]+" e "+num[B].lower())
    elif len(M) == 3:
        N = int(M[0])
        B = int(M[1])
        V = int(M[2])
        if N == 1:
            if B == 0:
                if V == 0:
                    print("Cem")
                    break
        if B < 2:
            print(num[N*100] +" e "+ num[B*10+V].lower())
        if B == 2:
            if V == 0:
                print(num[N*100] +" e "+ num[B*10+V].lower())
            else:
                print(num[N*100] +" e "+ num[B*10].lower() +(" e ")*Ç+ num[V].lower())
        if V == 0:
            V = 1234567
            Ç = 0
        if B >= 2:
            print(num[N*100] +" e "+ num[B*10].lower() +(" e ")*Ç+ num[V].lower())
    elif len(M) == 4:
        N = int(M[0])
        B = int(M[1])
        V = int(M[2])
        C = int(M[3])
        if C == 0:
            Ç = 0
        if B == 0:
            s = 0
        if V < 2:
            print(num[N]+" mil "+s*(num[B*100].lower())+ " e " +num[V*10+C].lower())
        if V == 2:
            if V == 0:
                print(num[N] +" mil "+ num[B*10+V].lower())
            else:
                print(num[N] +" mil "+ num[B*100].lower() +" e "+ num[V*10].lower()+(" e ")+num[C].lower())
        if V > 2:
            if B == 0:
                print(num[N] + " mil " + num[V*10].lower() + " e " + num[C].lower())
            if B > 0:
                print(num[N] + " mil "+num[B*100].lower() +" e " + num[V*10].lower() +" e "+ num[C].lower())
    if len(M) == 5:
        N = int(M[0])
        B = int(M[1])
        V = int(M[2])
        C = int(M[3])
        D = int(M[4])
        if C < 2:
            if N < 2:
                if V == 0:
                    print(num[N*10 + B]+" mil e "+num[C*10+D].lower())
                if V != 0:
                    print(num[N*10 + B]+" mil "+num[V*100].lower()+" e "+num[C*10].lower()+" "+num[D].lower())
            if N == 2:
                if B == 0:
                    if V == 0:
                        print(num[N*10 + B]+" mil "+num[C*10+D].lower())
                    if V > 0:
                        print(num[N*10 + B]+" mil "+num[V*100]+" e "+num[C*10+D].lower())
                if B > 0:
                    if V == 0:
                        print(num[N*10 + B]+" mil "+num[C*10+D].lower())
                    if V > 0:
                        print(num[N*10]+" "+num[B]+" mil "+num[V*100].lower()+" e "+num[C*10+D].lower())
            if N > 2:
                if V == 0:
                    if B == 0:
                        print(num[N*10] +" mil "+" e "+num[C*10+D].lower())
                    if B != 0:
                        print(num[N*10]+" "+num[B].lower()+" mil "+" e "+num[C*10+D].lower())
                if V != 0:
                    if B == 0:
                        print(num[N*10] +" mil "+num[V*100].lower()+" e "+num[C*10+D].lower())
                    if B != 0:
                        print(num[N*10]+" "+num[B].lower()+" mil "+num[V*100].lower()+" e "+num[C*10+D].lower())
        if C > 2:
            if N < 2:
                if V == 0:
                    print(num[N*10 + B]+" mil e "+num[C*10].lower()+" e "+num[D].lower())
                if V != 0:
                    print(num[N*10 + B]+" mil "+num[V*100].lower()+" e "+num[C*10].lower()+" "+num[D].lower())
            if N == 2:
                if B == 0:
                    if V == 0:
                        print(num[N*10 + B]+" mil "+num[C*10].lower()+" e "+num[D].lower())
                    if V > 0:
                        print(num[N*10 + B]+" mil "+num[V*100]+" e "+num[C*10].lower()+" e "+num[D].lower())
                if B > 0:
                    if V == 0:
                        print(num[N*10 + B]+" mil "+num[C*10].lower()+" e "+num[D].lower())
                    if V > 0:
                        print(num[N*10]+" "+num[B]+" mil "+num[V*100].lower()+" e "+num[C*10].lower()+" e "+num[D].lower())
            if N > 2:
                if V == 0:
                    if B == 0:
                        print(num[N*10] +" mil "+" e "+num[C*10].lower()+" e "+num[D].lower())
                    if B != 0:
                        print(num[N*10]+" "+num[B].lower()+" mil "+" e "+num[C*10].lower()+" e "+num[D].lower())
                if V != 0:
                    if B == 0:
                        print(num[N*10] +" mil "+num[V*100].lower()+" e "+num[C*10].lower()+" e "+num[D].lower())
                    if B != 0:
                        print(num[N*10]+" "+num[B].lower()+" mil "+num[V*100].lower()+" e "+num[C*10].lower()+" e "+num[D].lower())
        if C == 2:
            if D == 0:
                if N < 2:
                    if V == 0:
                        print(num[N*10 + B]+" mil e "+num[C*10+D].lower())
                    if V != 0:
                        print(num[N*10 + B]+" mil "+num[V*100].lower()+" e "+num[C*10].lower()+" "+num[D].lower())
                if N == 2:
                    if B == 0:
                        if V == 0:
                            print(num[N*10 + B]+" mil "+num[C*10+D].lower())
                        if V > 0:
                            print(num[N*10 + B]+" mil "+num[V*100]+" e "+num[C*10+D].lower())
                    if B > 0:
                        if V == 0:
                            print(num[N*10 + B]+" mil "+num[C*10+D].lower())
                        if V > 0:
                            print(num[N*10]+" "+num[B]+" mil "+num[V*100].lower()+" e "+num[C*10+D].lower())
                if N > 2:
                    if V == 0:
                        if B == 0:
                            print(num[N*10] +" mil "+" e "+num[C*10+D].lower())
                        if B != 0:
                            print(num[N*10]+" "+num[B].lower()+" mil "+" e "+num[C*10+D].lower())
                    if V != 0:
                        if B == 0:
                            print(num[N*10] +" mil "+num[V*100].lower()+" e "+num[C*10+D].lower())
                        if B != 0:
                            print(num[N*10]+" "+num[B].lower()+" mil "+num[V*100].lower()+" e "+num[C*10+D].lower())
            if D != 0:
                if N < 2:
                    if V == 0:
                        print(num[N*10 + B]+" mil e "+num[C*10].lower()+" e "+num[D].lower())
                    if V != 0:
                        print(num[N*10 + B]+" mil "+num[V*100].lower()+" e "+num[C*10].lower()+" "+num[D].lower())
                if N == 2:
                    if B == 0:
                        if V == 0:
                            print(num[N*10 + B]+" mil "+num[C*10].lower()+" e "+num[D].lower())
                        if V > 0:
                            print(num[N*10 + B]+" mil "+num[V*100]+" e "+num[C*10].lower()+" e "+num[D].lower())
                    if B > 0:
                        if V == 0:
                            print(num[N*10 + B]+" mil "+num[C*10].lower()+" e "+num[D].lower())
                        if V > 0:
                            print(num[N*10]+" "+num[B]+" mil "+num[V*100].lower()+" e "+num[C*10].lower()+" e "+num[D].lower())
                if N > 2:
                    if V == 0:
                        if B == 0:
                            print(num[N*10] +" mil "+" e "+num[C*10].lower()+" e "+num[D].lower())
                        if B != 0:
                            print(num[N*10]+" "+num[B].lower()+" mil "+" e "+num[C*10].lower()+" e "+num[D].lower())
                    if V != 0:
                        if B == 0:
                            print(num[N*10] +" mil "+num[V*100].lower()+" e "+num[C*10].lower()+" e "+num[D].lower())
                        if B != 0:
                            print(num[N*10]+" "+num[B].lower()+" mil "+num[V*100].lower()+" e "+num[C*10].lower()+" e "+num[D].lower())
# Out:
# Luis Miguel Carmona
# Matemática Aplicada
# DRE-119066153
#
# Programa que escreve por extenso um número de até 5 casas solicitado ao usuário
#
# Quantas vezes você quer repetir? 4
# Seu número: 1100
# Um mil cento e zero
# Seu número: 45641
# Quarenta cinco mil seiscentos e quarenta e um
# Seu número: 14256
# Quatorze mil duzentos e cinquenta seis
